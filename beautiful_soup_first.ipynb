# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://web-scraping-demo.zgulde.net/news')
soup = BeautifulSoup(response.text)

# %%
articles = soup.select('.grid.gap-y-12 > div')

# %%
summary = article.p.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b9e49bca37a6> in <module>
# ----> 1 summary = article.p.text
#
# NameError: name 'article' is not defined

# %%
def parse_news_article(article):
    title = article.h2.text
    date, author = article.select('.italic')[0].find_all('p')
    summary = article.find_all('p')[-1]   
    return {'title': title, 'date': date.text, 'author': author.text, 'summary': summary.text}

# %%
     response = requests.get('https://web-scraping-demo.zgulde.net/news')
     soup = BeautifulSoup(response.text)
     articles = soup.select('.grid.gap-y-12 > div')
     pd.DataFrame([parse_news_article(article) for article in articles])
# Out:
#                         title          date                author  \
# 0       evening process range   1981-02-07      By Traci Jackson
# 1              why Mrs either   1974-04-07      By Richard Green
# 2          reduce shake might   2000-08-10       By Erin Mcmahon
# 3          consumer carry who   2000-01-26        By Brian Foley
# 4             study draw book   1979-04-16          By Eric Hall
# 5   fast opportunity employee   1972-09-08    By Richard Summers
# 6           affect focus same   1982-07-08         By Todd Smith
# 7         human measure along   1983-01-01      By Rachel Martin
# 8          simply street each   1983-08-26      By Justin Hardin
# 9              many worry law   2020-09-01     By Todd Henry Jr.
# 10           really food stop   2017-03-10      By Janice Howard
# 11            walk sure three   1983-01-09   By Brandi Carpenter
#
#                                               summary
# 0   Happy letter get miss later without. Bed envir...
# ...

# %%
def get_person_info(article):
    name = article.h2.text
    quote = article.find_all('p')[0]
    email = article.find_all('p')[1]
    ph_number = article.find_all('p')[2]
    address = article.find_all('p')[-1]
     
    return {'name': name, 'quote': quote.text.strip(), 'email': email.text, 'ph_number': ph_number.text, 'address': address.text.strip()}

# %%
    response = requests.get('https://web-scraping-demo.zgulde.net/people')
    soup = BeautifulSoup(response.text)
    articles = soup.select('.person')
    #articles = soup.select('div', attrs = {'id':'people'})
    pd.DataFrame([get_person_info(article) for article in articles])
# Out:
#                 name                                         quote  \
# 0      Calvin Miller       "Virtual even-keeled pricing structure"
# 1     Zachary Rangel         "Switchable fault-tolerant moderator"
# 2  Jacqueline Larsen               "Open-source 24hour complexity"
# 3       Joy Alvarado  "Triple-buffered empowering standardization"
# 4      Amanda Waters            "Switchable dedicated focus group"
# 5     Patrick Carter  "Fully-configurable tertiary data-warehouse"
# 6      Erica Solomon         "Quality-focused value-added synergy"
# 7        Katie Jones       "Configurable non-volatile open system"
# 8         Ann Hurley               "Operative exuding flexibility"
# 9        Julie Heath   "Multi-tiered attitude-oriented capability"
#
#                                  email              ph_number  \
# 0                denisemorton@ross.net           650-355-4690
# 1            michellepayne@hotmail.com    +1-598-491-1615x991
# ...

# %%
#soup.select('#people')
#this code snippet doesn't work bc it finds every single record instead of one that repeats over and over.

# %%
soup.select('.person')
# Out:
# [<div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
#  <h2 class="text-2xl text-purple-800 name col-span-full border-b">Regina Nixon</h2>
#  <p class="quote col-span-full px-5 py-5 text-center text-gray-500">
#              "Open-architected methodical attitude"
#          </p>
#  <div class="grid grid-cols-9">
#  <i class="bi bi-envelope-fill text-purple-800"></i>
#  <p class="email col-span-8">qray@carter.info</p>
#  <i class="bi bi-telephone-fill text-purple-800"></i>
#  <p class="phone col-span-8">001-392-930-5188x825</p>
#  </div>
#  <div class="address grid grid-cols-9">
#  <i class="bi bi-geo-fill text-purple-800"></i>
#  <p class="col-span-8">
#                  42417 Fowler Junctions Suite 825 <br/>
#                  Dawnside, DE 69818
#              </p>
#  </div>
#  </div>,
#  <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
# ...

# %%
soup.select('.person')[0]
# Out:
# <div class="person border rounded px-3 py-5 grid grid-cols-2 gap-x-3 bg-purple-50 hover:shadow-lg transition duration-500">
# <h2 class="text-2xl text-purple-800 name col-span-full border-b">Regina Nixon</h2>
# <p class="quote col-span-full px-5 py-5 text-center text-gray-500">
#             "Open-architected methodical attitude"
#         </p>
# <div class="grid grid-cols-9">
# <i class="bi bi-envelope-fill text-purple-800"></i>
# <p class="email col-span-8">qray@carter.info</p>
# <i class="bi bi-telephone-fill text-purple-800"></i>
# <p class="phone col-span-8">001-392-930-5188x825</p>
# </div>
# <div class="address grid grid-cols-9">
# <i class="bi bi-geo-fill text-purple-800"></i>
# <p class="col-span-8">
#                 42417 Fowler Junctions Suite 825 <br/>
#                 Dawnside, DE 69818
#             </p>
# </div>
# </div>

# %%
people = soup.select('.person')

# %%
person = people[0]

# %%
person.h2.text
# Out:
# 'Regina Nixon'

# %%
person.p.text.strip()
# Out:
# '"Open-architected methodical attitude"'

# %%
person.select('.email')[0].text
# Out:
# 'qray@carter.info'

# %%
person.select('.phone')[0].text
# Out:
# '001-392-930-5188x825'

# %%
person.select('.address')[0].text.strip()
# Out:
# '42417 Fowler Junctions Suite 825 \n                Dawnside, DE 69818'

# %%
#person.find_all('p')[1].text  
#This also finds the email
# Out:
# 'qray@carter.info'

# %%
#person.find_all('p')[2].text
#This also finds the phone
# Out:
# '001-392-930-5188x825'

# %%
#person.find_all('p')[-1].text.strip()
#This also finds the address
# Out:
# '42417 Fowler Junctions Suite 825 \n                Dawnside, DE 69818'
